# %%
# %load_ext sparksql_magic

# %%
import os
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip
from utils import read_query

# %%
import os
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip
spark = (
    SparkSession.builder
    .appName("TestDataPlatform")
    .master("local[*]")
    .config('spark.jars', ','.join(os.path.join(dp, f) for dp, _, fs in os.walk('/home/jovyan/jars') for f in fs))
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.hadoop.fs.s3a.path.style.access", os.getenv("SPARK_S3_PATH_STYLE_ACCESS"))
    .config("spark.hadoop.fs.s3a.endpoint", os.getenv("SPARK_S3_ENDPOINT"))
    .config("spark.hadoop.fs.s3a.access.key", os.getenv("SPARK_S3_ACCESS_KEY"))
    .config("spark.hadoop.fs.s3a.secret.key", os.getenv("SPARK_S3_SECRET_KEY"))
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.sql.catalogImplementation", "hive")
    .config("spark.sql.warehouse.dir", os.getenv("SPARK_HIVE_WAREHOUSE_DIR"))
    .config("hive.metastore.uris", os.getenv("SPARK_HIVE_METASTORE_URIS"))
    .enableHiveSupport()
)
spark = configure_spark_with_delta_pip(spark).getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pyspark:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>TestDataPlatform</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
USER = "sa"
PASSWORD = "YourStrong@Passw0rd"
URL = "jdbc:sqlserver://sqlserver:1433;databaseName=c;encrypt=false;trustServerCertificate=true"

# %%
BUCKET = os.getenv("BUCKET", default="lhchdev")
CAPA = "brz"
FUENTE = "SOFMAC"
TABLA = "KPYMADEUDADOS"

# %%
spark.sql("create database if not exists brz;")
# Out:
# DataFrame[]

# %%
spark.sql(f"""
CREATE EXTERNAL TABLE IF NOT EXISTS {CAPA}.{FUENTE}_{TABLA} (
    cCodCorAde STRING COMMENT 'Código correlativo de adeudado',
    cDesAdeuda STRING COMMENT 'Descripción del adeudado'
)
USING DELTA
COMMENT 'Tabla de adeudados'
LOCATION 's3a://{BUCKET}/{CAPA}/{FUENTE}/{TABLA}'
;""")
# Out:
# DataFrame[]

# %%
df = read_query(query="""(
    SELECT * FROM SOFCMACHYO_BI_SNAP.DBO.KPYMADEUDADOS
)dym""",spark=spark,url=URL,user=USER,password=PASSWORD)

# %%
df.write.format("delta").insertInto(f"{CAPA}.{FUENTE}_{TABLA}", overwrite=True)

# %%
df.show(10,False)
# Out:
# +--------------------+---------------------------------+
# |cCodCorAde          |cDesAdeuda                       |
# +--------------------+---------------------------------+
# |00100000000000472   |AUQUI AUCCAPIÑA, ROBERT          |
# |00100000000000473   |MENDOZA MATA, NANCY ELIZABETH    |
# |00100000000000474   |VILCAÑAUAPA HUAROC, NANCY        |
# |00100000000000475   |ROJAS FABIAN, CLEDY FLORENTINA   |
# |00100000000000476   |ORDOÑEZ VALLADOLID, RAUL ERASMO  |
# |00100000000000477   |HUANCHAJURI CARRION, YOLANDA J...|
# |00100000000000478   |VALLEJO MERLO, GUISSELLA NANCY   |
# |00100000000000479   |CAMPOS PACHECO, DELIA            |
# |00100000000000480   |PEREZ HUANUCO, MICHEL ELI        |
# |00100000000000481   |FLORES SAENZ, JULIANA PAOLA      |
# +--------------------+---------------------------------+
# only showing top 10 rows

# %%
# %%sparksql
# SHOW DATABASES;
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td></tr><tr><td>bronze</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>silver</td></tr></table>

# %%
# %%sparksql
# DROP DATABASE IF EXISTS landing;
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE DATABASE IF NOT EXISTS bronze
# LOCATION 's3a://warehouse/bronze/';
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE DATABASE IF NOT EXISTS silver
# LOCATION 's3a://warehouse/silver/';
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE DATABASE IF NOT EXISTS gold
# LOCATION 's3a://warehouse/gold/';
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
df = spark.read.format("parquet").load("./data/STA_TIPO_CAMBIO/")

# %%
df.show(10,False)

# %%
df.write.format("parquet").saveAsTable("bronze.STA_TIPO_CAMBIO")

# %%
df.write.format("delta").saveAsTable("silver.STA_TIPO_CAMBIO")

# %%
# %%sparksql
# DROP TABLE IF EXISTS bronze.datos_aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# SHOW TABLES IN bronze;
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td><td style="font-weight: bold">tableName</td><td style="font-weight: bold">isTemporary</td></tr><tr><td>bronze</td><td>sta_tipo_cambio</td><td>False</td></tr><tr><td></td><td>aeropuerto</td><td>False</td></tr></table>

# %%
schema = StructType([
    StructField("fecha", StringType(), True),
    StructField("tipocambio", StringType(), True)
])
df = spark.read.format("parquet").load("./data/STA_TIPO_CAMBIO/")

# %%
# %%sparksql
# CREATE OR REPLACE TABLE silver.sta_tipo_cambio_2(
#     fecha STRING,
#     tipocambio STRING
# )
# USING DELTA
# LOCATION 's3a://warehouse/silver/sta_tipo_cambio_2';
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# SELECT * FROM silver.sta_tipo_cambio_2
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">fecha</td><td style="font-weight: bold">tipocambio</td></tr></table>

# %%
df = df.withColumnRenamed("Fecha", "fecha") \
       .withColumnRenamed("Tipocambio", "tipocambio")
df.write.format("delta").mode("overwrite").saveAsTable("silver.STA_TIPO_CAMBIO_2")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 df = df.withColumnRenamed("Fecha", "fecha") \
#       2        .withColumnRenamed("Tipocambio", "tipocambio")
# ----> 3 df.write.format("delta").mode("overwrite").saveAsTable("silver.STA_TIPO_CAMBIO_2")
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:1586, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#    1584 if format is not None:
#    1585     self.format(format)
# -> 1586 self._jwrite.saveAsTable(name)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DELTA_FAILED_TO_MERGE_FIELDS] Failed to merge fields 'fecha' and 'fecha'

# %% [markdown]
# Si previmante creaste un DDL y no es compatible en tipo de datos con la información que vas a ingresar producira errores.

# %%
# %%sparksql
# SELECT * FROM silver.sta_tipo_cambio_2

# %%
# %%sparksql
# DESCRIBE EXTENDED silver.sta_tipo_cambio
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">col_name</td><td style="font-weight: bold">data_type</td><td style="font-weight: bold">comment</td></tr><tr><td>Fecha</td><td>date</td><td>null</td></tr><tr><td>TipoCambio</td><td>decimal(10,2)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>spark_catalog.silver.sta_tipo_cambio</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>s3a://warehouse/silver/sta_tipo_cambio</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>jovyan</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></table>

# %%
# %%sparksql
# CREATE EXTERNAL TABLE IF NOT EXISTS bronze.datos_aeropuerto (
#     anio INT,
#     mes INT,
#     entidad_prestadora STRING,
#     concesion STRING,
#     aeropuerto STRING,
#     tipo_vuelo STRING,
#     total_pasajeros INT
# )
# USING DELTA
# LOCATION 's3a://warehouse/bronze/datos_aeropuerto_raw';
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE OR REPLACE TEMP VIEW aeropuerto
# USING csv
# OPTIONS (
#     path "s3a://warehouse/landing/data/datos_aeropuerto.csv",
#     header "true",
#     delimiter "," ,
#     encoding "UTF-8"
# );
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# DELETE FROM bronze.datos_aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">num_affected_rows</td></tr><tr><td>7</td></tr></table>

# %%
# %%sparksql
# SELECT * FROM aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">anio</td><td style="font-weight: bold">mes</td><td style="font-weight: bold">entidad_prestadora</td><td style="font-weight: bold">concesion</td><td style="font-weight: bold">aeropuerto</td><td style="font-weight: bold">tipo_vuelo</td><td style="font-weight: bold">total_pasajeros</td></tr><tr><td>2023</td><td>1</td><td>LATAM Airlines</td><td>Lima - Perú</td><td>Jorge Chávez</td><td>Nacional</td><td>150000</td></tr><tr><td>2023</td><td>1</td><td>Avianca</td><td>Bogotá - Colombia</td><td>El Dorado</td><td>Internacional</td><td>200000</td></tr><tr><td>2023</td><td>2</td><td>LATAM Airlines</td><td>Lima - Perú</td><td>Jorge Chávez</td><td>Internacional</td><td>120000</td></tr><tr><td>2023</td><td>2</td><td>Copa Airlines</td><td>Panamá - Panamá</td><td>Tocumen</td><td>Internacional</td><td>90000</td></tr><tr><td>2023</td><td>3</td><td>Viva Air</td><td>Medellín - Colombia</td><td>José María Córdova</td><td>Nacional</td><td>80000</td></tr><tr><td>2024</td><td>1</td><td>LATAM Airlines</td><td>Santiago - Chile</td><td>Arturo Merino Benítez</td><td>Nacional</td><td>160000</td></tr><tr><td>2024</td><td>1</td><td>American Airlines</td><td>Miami - USA</td><td>Miami International</td><td>Internacional</td><td>250000</td></tr></table>

# %%
# %%sparksql
# INSERT INTO bronze.datos_aeropuerto
# SELECT * FROM aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# DESCRIBE EXTENDED aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">col_name</td><td style="font-weight: bold">data_type</td><td style="font-weight: bold">comment</td></tr><tr><td>anio</td><td>string</td><td>null</td></tr><tr><td>mes</td><td>string</td><td>null</td></tr><tr><td>entidad_prestadora</td><td>string</td><td>null</td></tr><tr><td>concesion</td><td>string</td><td>null</td></tr><tr><td>aeropuerto</td><td>string</td><td>null</td></tr><tr><td>tipo_vuelo</td><td>string</td><td>null</td></tr><tr><td>total_pasajeros</td><td>string</td><td>null</td></tr></table>

# %%
# %%sparksql
# DESCRIBE EXTENDED bronze.datos_aeropuerto
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">col_name</td><td style="font-weight: bold">data_type</td><td style="font-weight: bold">comment</td></tr><tr><td>anio</td><td>int</td><td>null</td></tr><tr><td>mes</td><td>int</td><td>null</td></tr><tr><td>entidad_prestadora</td><td>string</td><td>null</td></tr><tr><td>concesion</td><td>string</td><td>null</td></tr><tr><td>aeropuerto</td><td>string</td><td>null</td></tr><tr><td>tipo_vuelo</td><td>string</td><td>null</td></tr><tr><td>total_pasajeros</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>spark_catalog.bronze.datos_aeropuerto</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Location</td><td>s3a://warehouse/bronze/datos_aeropuerto_raw</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>jovyan</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></table>

# %%
# %%sparksql
# SHOW TABLES IN bronze;
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">namespace</td><td style="font-weight: bold">tableName</td><td style="font-weight: bold">isTemporary</td></tr><tr><td>bronze</td><td>datos_aeropuerto</td><td>False</td></tr><tr><td>bronze</td><td>sta_tipo_cambio</td><td>False</td></tr><tr><td></td><td>aeropuerto</td><td>False</td></tr></table>
